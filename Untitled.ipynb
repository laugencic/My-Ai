# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

data=pd.read_csv(r"C:\Users\user\Desktop\Projects\Finance\Fraud\carprices.csv")

data.columns
# Out:
# Index(['Mileage', 'Age(yrs)', 'Sell Price($)'], dtype='object')

# %%
#checking the relationship between the variables using scatter plot and line of best fit
a=data['Mileage']
b=data['Age(yrs)']
c=data['Sell Price($)']

# plt.scatter(a,b)
# m,c=np.polyfit(a,b,1) #fids polynomial that fits the data
# b_fit=m*a+c
# plt.plot(a,b_fit)

plt.scatter(b,c)
m,intercept=np.polyfit(b,c,1)
c_fit=m*b+intercept
plt.plot(b,c_fit)

# %%
#splitting data 
X=data[['Mileage','Age(yrs)']]
y=data['Sell Price($)']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=LinearRegression()
model.fit(X_train,y_train)
model.predict(X_test)
# Out:
# array([13333.79588266, 29793.34636156, 27202.71871503, 16505.09399517])

# %%
#Checking the accuracy of the model
model.score(X_test,y_test)
# Out:
# 0.8884396178939942
